# %%
##

# %% [markdown]
# #### Environment test

# %%
import sys
from pathlib import Path

print("Python executable:")
print(sys.executable)

print("\nCurrent working directory:")
print(Path.cwd())
# Out:
# Python executable:
# C:\Users\Wilson\anaconda3\envs\marketlens\python.exe
#
# Current working directory:
# C:\Users\Wilson\Documents\OpenAI\MarketLens\notebooks

# %%
# ensure that working directory = the project root

import os

os.chdir(r"C:\Users\Wilson\Documents\OpenAI\MarketLens")
print(os.getcwd())
# Out:
# C:\Users\Wilson\Documents\OpenAI\MarketLens

# %% [markdown]
# #### Package import test

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import yfinance as yf
from fredapi import Fred
from dotenv import load_dotenv

print("All required packages imported successfully.")
# Out:
# All required packages imported successfully.

# %% [markdown]
# #### Folder check

# %%
from pathlib import Path

required_paths = [
    "data/raw",
    "data/processed",
    "notebooks",
    "src",
    "dashboard",
    "reports",
    "website",
    ".github/workflows",
]

for path in required_paths:
    p = Path(path)
    print(f"{path}: {'OK' if p.exists() else 'MISSING'}")
# Out:
# data/raw: OK
# data/processed: OK
# notebooks: OK
# src: OK
# dashboard: OK
# reports: OK
# website: OK
# .github/workflows: OK

# %% [markdown]
# #### Save setup report

# %%
from pathlib import Path
from datetime import datetime

report_path = Path("reports/setup_check.txt")

content = f"""
MarketLens Setup Check

Status: Setup test completed successfully.
Project root: {Path.cwd()}
Timestamp: {datetime.now()}

Checked:
- Jupyter kernel
- Python imports
- Project folders
"""

report_path.write_text(content.strip(), encoding="utf-8")

print(f"Setup report saved to: {report_path}")
# Out:
# Setup report saved to: reports\setup_check.txt
